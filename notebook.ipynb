# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("MobileFeatureMaterialization")
    .master("local[*]")
    .getOrCreate()
)

# %%
import os
from pathlib import Path

print("cwd:", os.getcwd())
print("files:", os.listdir()[:50])
print("resolved path:", Path("mobiles.json").resolve())
# Out:
# cwd: /content
# files: ['.config', 'sample_data']
# resolved path: /content/mobiles.json

# %%
# load the JSON file into a Spark DataFrame (uses existing `p` and `spark`)
if 'df_raw' in globals():
    print("df_raw already loaded")
else:
    if not Path(p).exists():
        raise FileNotFoundError(p)
    df_raw = spark.read.json(str(Path(p)))

print("rows:", df_raw.count())
df_raw.printSchema()
df_raw.show(20, truncate=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-389172889.py in <cell line: 0>()
#       4 else:
#       5     if not Path(p).exists():
# ----> 6         raise FileNotFoundError(p)
#       7     df_raw = spark.read.json(str(Path(p)))
#       8
#
# FileNotFoundError: C:\Users\Animesh Modi\Desktop\Apache_Kafka\FDP\tortoise\mobiles.json

# %%
# Example Windows absolute path
p = r"C:\Users\Animesh Modi\Desktop\Apache_Kafka\FDP\tortoise\mobiles.json"
from pathlib import Path
if Path(p).exists():
    df_raw = spark.read.json(str(Path(p)))
else:
    raise FileNotFoundError(p)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-657692286.py in <cell line: 0>()
#       5     df_raw = spark.read.json(str(Path(p)))
#       6 else:
# ----> 7     raise FileNotFoundError(p)
#
# FileNotFoundError: C:\Users\Animesh Modi\Desktop\Apache_Kafka\FDP\tortoise\mobiles.json
